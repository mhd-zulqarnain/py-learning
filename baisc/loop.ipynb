# %%
#calculate using while and for loop
n= 10
sum =0
count =1
# for i in range (n+1):
#     sum +=i
# print(sum)

while count<=n:
    sum=sum+count
    count+=1
print(f"the sum is {sum}")
# Out:
# the sum is 55

# %%
# the break and continue statement

# for i in range(2,20):
#     if(i%2==0):
#         continue
#     else:
#         print(i)


for i in range(20, 2, -3):
     if i % 3 == 0:
        break
     else:
      print(i)
# Out:
# 20
# 17
# 14
# 11
# 8
# 5

# %%
#loop
# for i in range(1,10):
#     print(i)

#third parameter in range used for step 
# for i in range(1,10 ,2):
#     print(i)

for i in range(5,1 ,-1):
    for j in range(1,5,3):
     print(f"i:{i}, j:{j}")
# Out:
# i:5, j:1
# i:5, j:4
# i:4, j:1
# i:4, j:4
# i:3, j:1
# i:3, j:4
# i:2, j:1
# i:2, j:4
